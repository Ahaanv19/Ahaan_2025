// %% [raw]
// ---
// title: FRQ 2 Homework 2024
// comments: true
// layout: post
// permalink: /2024/frq2-lesson-homework/
// description: FRQ 2 Homework 2024
// author: Ahaan
// ---

// %% [markdown]
// # Proof of Completion and Running on Open Coding Society Code Runner

// %% [markdown]
// <td><img src="{{site.baseurl}}/images/Screenshot 2026-01-21 at 11.42.17 AM.png" height="350" title="Home" alt=""></td>
